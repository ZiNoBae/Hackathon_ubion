# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DF 불러오기

# %%
df0 = pd.read_csv('./after_preprocessing_data/df_all_0629.csv')
df0
# Out:
#          자치구         계약일  건물면적(㎡)   층      KOSPI종가  Fed기준금리  \
# 0        노원구  2016-01-01    39.96  10  1961.310059     0.34
# 1        성동구  2016-01-01    75.37  10  1961.310059     0.34
# 2        금천구  2016-01-01    84.83   3  1961.310059     0.34
# 3        은평구  2016-01-01   101.97   9  1961.310059     0.34
# 4        노원구  2016-01-01    84.59  10  1961.310059     0.34
# ...      ...         ...      ...  ..          ...      ...
# 536092   서초구  2022-12-31   152.33   9  2236.399902     4.10
# 536093   송파구  2022-12-31    84.71  11  2236.399902     4.10
# 536094   송파구  2022-12-31    84.90  24  2236.399902     4.10
# 536095   양천구  2022-12-31    64.02   5  2236.399902     4.10
# 536096  동대문구  2022-12-31    84.97  11  2236.399902     4.10
#
#         국제유가(Dubai)($/배럴)  부동산거래량  국고채5년(평균)  국고채10년(평균)  ...  BOK기준금리  건물연식  \
# 0                    26.9    9894       1.77        2.03  ...     1.50    25
# 1                    26.9    9894       1.77        2.03  ...     1.50    26
# 2                    26.9    9894       1.77        2.03  ...     1.50    14
# 3                    26.9    9894       1.77        2.03  ...     1.50     6
# 4                    26.9    9894       1.77        2.03  ...     1.50    26
# ...                   ...     ...        ...         ...  ...      ...   ...
# 536092               77.2    3698       3.59        3.54  ...     3.25    18
# 536093               77.2    3698       3.59        3.54  ...     3.25    34
# 536094               77.2    3698       3.59        3.54  ...     3.25    14
# 536095               77.2    3698       3.59        3.54  ...     3.25    26
# 536096               77.2    3698       3.59        3.54  ...     3.25    19
#
#         GDP대비가계부채비율     환율종가  선행지수순환변동치         EPU  장단기금리spread      금값종가  \
# 0              83.3  1175.45       99.6  177.148845         0.14  1,060.74
# 1              83.3  1175.45       99.6  177.148845         0.14  1,060.74
# 2              83.3  1175.45       99.6  177.148845         0.14  1,060.74
# 3              83.3  1175.45       99.6  177.148845         0.14  1,060.74
# 4              83.3  1175.45       99.6  177.148845         0.14  1,060.74
# ...             ...      ...        ...         ...          ...       ...
# 536092        105.0  1260.92       99.1  169.662386         0.39  1,824.40
# 536093        105.0  1260.92       99.1  169.662386         0.39  1,824.40
# 536094        105.0  1260.92       99.1  169.662386         0.39  1,824.40
# 536095        105.0  1260.92       99.1  169.662386         0.39  1,824.40
# 536096        105.0  1260.92       99.1  169.662386         0.39  1,824.40
#
#         LTV 물건금액(만원)
# 0       0.7    18000
# 1       0.7    55200
# 2       0.7    36800
# 3       0.7    67600
# 4       0.7    30300
# ...     ...      ...
# 536092  0.0   250000
# 536093  0.2   138000
# 536094  0.0   172000
# 536095  0.4    37000
# 536096  0.4    76500
#
# [536097 rows x 22 columns]

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536097 entries, 0 to 536096
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   자치구                536097 non-null  object
#  1   계약일                536097 non-null  object
#  2   건물면적(㎡)            536097 non-null  float64
#  3   층                  536097 non-null  int64
#  4   KOSPI종가            536097 non-null  float64
#  5   Fed기준금리            536097 non-null  float64
#  6   국제유가(Dubai)($/배럴)  536097 non-null  float64
#  7   부동산거래량             536097 non-null  int64
#  8   국고채5년(평균)          536097 non-null  float64
#  9   국고채10년(평균)         536097 non-null  float64
#  10  회사채3년(평균)          536097 non-null  float64
#  11  CD91물(평균)          536097 non-null  float64
#  12  BOK기준금리            536097 non-null  float64
#  13  건물연식               536097 non-null  int64
#  14  GDP대비가계부채비율        536097 non-null  float64
#  15  환율종가               536097 non-null  float64
#  16  선행지수순환변동치          536097 non-null  float64
#  17  EPU                536097 non-null  float64
#  18  장단기금리spread        536097 non-null  float64
#  19  금값종가               536097 non-null  object
#  20  LTV                536097 non-null  float64
#  21  물건금액(만원)           536097 non-null  int64
# dtypes: float64(15), int64(4), object(3)
# memory usage: 90.0+ MB

# %%
df0['금값종가'] = df0['금값종가'].str.replace(',','').astype(float)

# %% [markdown]
# ## LTV 컬럼 추가
# - 계약일
# - 거래가격(=물건금액)
# > 2가지 조건을 고려하여 LTV 값 대입
#
# - 서울
#     - 투기과열지구 : 서울 전역 포함(17.08.02 ~ 23.01)
#     - 서울 내에서 투기지역 구분 의미 X
#
# - 고려하지 못한 조건
#     - 소득
#     - 주택 소유 및 다주택 여부

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536097 entries, 0 to 536096
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   자치구                536097 non-null  object
#  1   계약일                536097 non-null  object
#  2   건물면적(㎡)            536097 non-null  float64
#  3   층                  536097 non-null  int64
#  4   KOSPI종가            536097 non-null  float64
#  5   Fed기준금리            536097 non-null  float64
#  6   국제유가(Dubai)($/배럴)  536097 non-null  float64
#  7   부동산거래량             536097 non-null  int64
#  8   국고채5년(평균)          536097 non-null  float64
#  9   국고채10년(평균)         536097 non-null  float64
#  10  회사채3년(평균)          536097 non-null  float64
#  11  CD91물(평균)          536097 non-null  float64
#  12  BOK기준금리            536097 non-null  float64
#  13  건물연식               536097 non-null  int64
#  14  GDP대비가계부채비율        536097 non-null  float64
#  15  환율종가               536097 non-null  float64
#  16  선행지수순환변동치          536097 non-null  float64
#  17  EPU                536097 non-null  float64
#  18  장단기금리spread        536097 non-null  float64
#  19  금값종가               536097 non-null  float64
#  20  LTV                536097 non-null  float64
#  21  물건금액(만원)           536097 non-null  int64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 90.0+ MB

# %% [markdown]
# # Train/Test Split

# %%
# Train : 2016-2020
# Test : 2021-2022

df0['계약일'] = pd.to_datetime(df0['계약일'])

# %%
train_df = df0.loc[df0['계약일'] < '2021']

# %%
test_df = df0.loc[df0['계약일'] >= '2021']

# %% [markdown]
# ## feature & target split

# %%
# Train Split
# feature & target  split

X_train_df = train_df.drop('물건금액(만원)', axis=1)
y = train_df['물건금액(만원)']

# X_train : 숫자형 컬럼만 
X_train = X_train_df.select_dtypes([np.number])

# %%
# Test Split
# feature & target  split

X_test_df = test_df.drop('물건금액(만원)', axis=1)
y_test = test_df['물건금액(만원)']

# X_test : 숫자형 컬럼만 
X_test = X_test_df.select_dtypes([np.number])

# %% [markdown]
# ---

# %% [markdown]
# # Scaling
# 1. Features - minMax
# 2. Target - Log

# %%
# minMax
from sklearn.preprocessing import MinMaxScaler

# Scaler 객체 생성
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
# y -> log 변환

# Train
y_scaled = np.log10(y)
# y_scaled

# Test
y_test_scaled = np.log10(y_test)
y_test_scaled
# Out:
# 453170    4.716003
# 453171    4.722634
# 453172    4.380211
# 453173    5.079181
# 453174    4.361728
#             ...
# 536092    5.397940
# 536093    5.139879
# 536094    5.235528
# 536095    4.568202
# 536096    4.883661
# Name: 물건금액(만원), Length: 82927, dtype: float64

# %% [markdown]
# # OLS - Scaling 후

# %% [markdown]
# ## OLS_1

# %%
# OLS_1
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                 2.582e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        10:55:07   Log-Likelihood:             1.3125e+05
# No. Observations:              453170   AIC:                        -2.625e+05
# Df Residuals:                  453150   BIC:                        -2.622e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6089      0.008    550.352      0.000       4.592       4.625
# 건물면적(㎡)               2.2003      0.004    584.433      0.000       2.193       2.208
# 층                     0.2745      0.003     84.702      0.000       0.268       0.281
# KOSPI종가               0.0245      0.007      3.762      0.000       0.012       0.037
# Fed기준금리              -0.1347      0.004    -35.789      0.000      -0.142      -0.127
# 국제유가(Dubai)($/배럴)     0.1407      0.004     37.917      0.000       0.133       0.148
# 부동산거래량                0.0139      0.002      7.017      0.000       0.010       0.018
# 국고채5년(평균)            -0.3033      0.020    -15.210      0.000      -0.342      -0.264
# 국고채10년(평균)            0.2631      0.015     18.017      0.000       0.234       0.292
# 회사채3년(평균)             0.1205      0.006     20.605      0.000       0.109       0.132
# CD91물(평균)            -0.0680      0.009     -7.952      0.000      -0.085      -0.051
# BOK기준금리              -0.0937      0.007    -13.128      0.000      -0.108      -0.080
# 건물연식                 -0.0047      0.002     -2.689      0.007      -0.008      -0.001
# GDP대비가계부채비율          -0.0313      0.006     -5.138      0.000      -0.043      -0.019
# 환율종가                  0.0174      0.003      5.478      0.000       0.011       0.024
# 선행지수순환변동치             0.1224      0.005     25.823      0.000       0.113       0.132
# EPU                  -0.0123      0.002     -6.301      0.000      -0.016      -0.009
# 장단기금리spread          -0.2422      0.009    -26.906      0.000      -0.260      -0.225
# 금값종가                 -0.0345      0.006     -5.801      0.000      -0.046      -0.023
# LTV                  -0.2774      0.002   -130.555      0.000      -0.282      -0.273
# ==============================================================================
# Omnibus:                    10917.420   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12453.145
# Skew:                           0.347   Prob(JB):                         0.00
# Kurtosis:                       3.420   Cond. No.                         208.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_1
from statsmodels.stats.outliers_influence import variance_inflation_factor

def feature_engineering_XbyVIF(X_scaled):
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(X_scaled.values,i)
                         for i in range(X_scaled.shape[1])]
    vif["Feature"] = X_scaled.columns
    return vif

# %%
# VIF_1
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#      VIF_Factor            Feature
# 0      6.314023            건물면적(㎡)
# 1      5.098651                  층
# 2    154.494903            KOSPI종가
# 3     52.497283            Fed기준금리
# 4     66.573570  국제유가(Dubai)($/배럴)
# 5     10.730366             부동산거래량
# 6   1173.018522          국고채5년(평균)
# 7    832.076790         국고채10년(평균)
# 8    125.388992          회사채3년(평균)
# 9    277.282846          CD91물(평균)
# 10   255.057634            BOK기준금리
# 11     5.609136               건물연식
# 12   106.724808        GDP대비가계부채비율
# 13    27.314418               환율종가
# 14   120.858568          선행지수순환변동치
# 15     5.533175                EPU
# 16   205.749795        장단기금리spread
# 17    65.173930               금값종가
# 18    28.104304                LTV

# %%
X_scaled.drop('국고채5년(평균)', axis=1, inplace=True)

# %%
# OLS_2
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                 2.723e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        10:57:58   Log-Likelihood:             1.3113e+05
# No. Observations:              453170   AIC:                        -2.622e+05
# Df Residuals:                  453151   BIC:                        -2.620e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6684      0.007    630.145      0.000       4.654       4.683
# 건물면적(㎡)               2.2007      0.004    584.404      0.000       2.193       2.208
# 층                     0.2744      0.003     84.641      0.000       0.268       0.281
# KOSPI종가               0.0224      0.007      3.440      0.001       0.010       0.035
# Fed기준금리              -0.1507      0.004    -41.658      0.000      -0.158      -0.144
# 국제유가(Dubai)($/배럴)     0.1399      0.004     37.678      0.000       0.133       0.147
# 부동산거래량                0.0148      0.002      7.462      0.000       0.011       0.019
# 국고채10년(평균)            0.0850      0.009      9.740      0.000       0.068       0.102
# 회사채3년(평균)             0.0940      0.006     16.840      0.000       0.083       0.105
# CD91물(평균)            -0.1190      0.008    -15.116      0.000      -0.134      -0.104
# BOK기준금리              -0.1403      0.006    -21.776      0.000      -0.153      -0.128
# 건물연식                 -0.0045      0.002     -2.569      0.010      -0.008      -0.001
# GDP대비가계부채비율          -0.0059      0.006     -1.002      0.317      -0.017       0.006
# 환율종가                  0.0348      0.003     11.717      0.000       0.029       0.041
# 선행지수순환변동치             0.1303      0.005     27.663      0.000       0.121       0.140
# EPU                  -0.0188      0.002     -9.844      0.000      -0.023      -0.015
# 장단기금리spread          -0.3313      0.007    -48.462      0.000      -0.345      -0.318
# 금값종가                 -0.0573      0.006     -9.975      0.000      -0.069      -0.046
# LTV                  -0.2719      0.002   -129.830      0.000      -0.276      -0.268
# ==============================================================================
# Omnibus:                    10950.103   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12468.481
# Skew:                           0.349   Prob(JB):                         0.00
# Kurtosis:                       3.417   Cond. No.                         102.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_scaled.drop('GDP대비가계부채비율', axis=1, inplace=True)

# %%
# OLS_3
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                 2.883e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:00:03   Log-Likelihood:             1.3113e+05
# No. Observations:              453170   AIC:                        -2.622e+05
# Df Residuals:                  453152   BIC:                        -2.620e+05
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6659      0.007    666.072      0.000       4.652       4.680
# 건물면적(㎡)               2.2009      0.004    585.580      0.000       2.194       2.208
# 층                     0.2744      0.003     84.657      0.000       0.268       0.281
# KOSPI종가               0.0223      0.007      3.426      0.001       0.010       0.035
# Fed기준금리              -0.1523      0.003    -47.300      0.000      -0.159      -0.146
# 국제유가(Dubai)($/배럴)     0.1391      0.004     38.321      0.000       0.132       0.146
# 부동산거래량                0.0146      0.002      7.396      0.000       0.011       0.018
# 국고채10년(평균)            0.0850      0.009      9.731      0.000       0.068       0.102
# 회사채3년(평균)             0.0928      0.005     17.051      0.000       0.082       0.103
# CD91물(평균)            -0.1188      0.008    -15.093      0.000      -0.134      -0.103
# BOK기준금리              -0.1371      0.006    -24.607      0.000      -0.148      -0.126
# 건물연식                 -0.0045      0.002     -2.593      0.010      -0.008      -0.001
# 환율종가                  0.0345      0.003     11.675      0.000       0.029       0.040
# 선행지수순환변동치             0.1300      0.005     27.658      0.000       0.121       0.139
# EPU                  -0.0189      0.002     -9.887      0.000      -0.023      -0.015
# 장단기금리spread          -0.3299      0.007    -49.337      0.000      -0.343      -0.317
# 금값종가                 -0.0606      0.005    -12.724      0.000      -0.070      -0.051
# LTV                  -0.2712      0.002   -138.267      0.000      -0.275      -0.267
# ==============================================================================
# Omnibus:                    10957.090   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12478.780
# Skew:                           0.349   Prob(JB):                         0.00
# Kurtosis:                       3.417   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_3
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#     VIF_Factor            Feature
# 0     6.276301            건물면적(㎡)
# 1     5.088876                  층
# 2   147.533788            KOSPI종가
# 3    38.202163            Fed기준금리
# 4    63.058427  국제유가(Dubai)($/배럴)
# 5    10.624845             부동산거래량
# 6   236.508098         국고채10년(평균)
# 7   109.605469          회사채3년(평균)
# 8   262.394074          CD91물(평균)
# 9   184.745717            BOK기준금리
# 10    5.579572               건물연식
# 11   16.695271               환율종가
# 12  116.742593          선행지수순환변동치
# 13    5.397132                EPU
# 14  150.826049        장단기금리spread
# 15   35.769547               금값종가
# 16   22.332139                LTV

# %%
X_scaled.drop('CD91물(평균)', axis=1, inplace=True)

# %%
# OLS_4
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                 3.060e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:00:35   Log-Likelihood:             1.3102e+05
# No. Observations:              453170   AIC:                        -2.620e+05
# Df Residuals:                  453153   BIC:                        -2.618e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6085      0.006    783.182      0.000       4.597       4.620
# 건물면적(㎡)               2.2017      0.004    585.704      0.000       2.194       2.209
# 층                     0.2744      0.003     84.611      0.000       0.268       0.281
# KOSPI종가               0.0478      0.006      7.607      0.000       0.035       0.060
# Fed기준금리              -0.1603      0.003    -50.428      0.000      -0.166      -0.154
# 국제유가(Dubai)($/배럴)     0.1411      0.004     38.897      0.000       0.134       0.148
# 부동산거래량                0.0109      0.002      5.555      0.000       0.007       0.015
# 국고채10년(평균)            0.0047      0.007      0.675      0.500      -0.009       0.018
# 회사채3년(평균)             0.1173      0.005     22.580      0.000       0.107       0.127
# BOK기준금리              -0.1912      0.004    -44.854      0.000      -0.200      -0.183
# 건물연식                 -0.0045      0.002     -2.588      0.010      -0.008      -0.001
# 환율종가                  0.0413      0.003     14.134      0.000       0.036       0.047
# 선행지수순환변동치             0.1558      0.004     35.570      0.000       0.147       0.164
# EPU                  -0.0171      0.002     -8.981      0.000      -0.021      -0.013
# 장단기금리spread          -0.3065      0.007    -47.111      0.000      -0.319      -0.294
# 금값종가                 -0.0543      0.005    -11.457      0.000      -0.064      -0.045
# LTV                  -0.2696      0.002   -137.616      0.000      -0.273      -0.266
# ==============================================================================
# Omnibus:                    11060.325   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12601.150
# Skew:                           0.351   Prob(JB):                         0.00
# Kurtosis:                       3.418   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_4
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#     VIF_Factor            Feature
# 0     6.244076            건물면적(㎡)
# 1     5.070018                  층
# 2   146.832134            KOSPI종가
# 3    37.521144            Fed기준금리
# 4    63.034165  국제유가(Dubai)($/배럴)
# 5    10.428258             부동산거래량
# 6   182.417487         국고채10년(평균)
# 7    97.567990          회사채3년(평균)
# 8    48.737819            BOK기준금리
# 9     5.556260               건물연식
# 10   15.734377               환율종가
# 11  102.829568          선행지수순환변동치
# 12    5.389453                EPU
# 13  150.254562        장단기금리spread
# 14   34.152116               금값종가
# 15   21.152048                LTV

# %%
X_scaled.drop('국고채10년(평균)', axis=1, inplace=True)

# %%
# OLS_5
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                 3.264e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:01:40   Log-Likelihood:             1.3102e+05
# No. Observations:              453170   AIC:                        -2.620e+05
# Df Residuals:                  453154   BIC:                        -2.618e+05
# Df Model:                          15
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6077      0.006    800.420      0.000       4.596       4.619
# 건물면적(㎡)               2.2017      0.004    585.707      0.000       2.194       2.209
# 층                     0.2744      0.003     84.611      0.000       0.268       0.281
# KOSPI종가               0.0473      0.006      7.581      0.000       0.035       0.059
# Fed기준금리              -0.1598      0.003    -51.407      0.000      -0.166      -0.154
# 국제유가(Dubai)($/배럴)     0.1410      0.004     38.903      0.000       0.134       0.148
# 부동산거래량                0.0108      0.002      5.535      0.000       0.007       0.015
# 회사채3년(평균)             0.1195      0.004     29.643      0.000       0.112       0.127
# BOK기준금리              -0.1900      0.004    -49.252      0.000      -0.198      -0.182
# 건물연식                 -0.0045      0.002     -2.579      0.010      -0.008      -0.001
# 환율종가                  0.0415      0.003     14.345      0.000       0.036       0.047
# 선행지수순환변동치             0.1571      0.004     39.402      0.000       0.149       0.165
# EPU                  -0.0170      0.002     -8.956      0.000      -0.021      -0.013
# 장단기금리spread          -0.3050      0.006    -49.832      0.000      -0.317      -0.293
# 금값종가                 -0.0552      0.005    -12.073      0.000      -0.064      -0.046
# LTV                  -0.2695      0.002   -138.157      0.000      -0.273      -0.266
# ==============================================================================
# Omnibus:                    11059.074   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12599.481
# Skew:                           0.351   Prob(JB):                         0.00
# Kurtosis:                       3.418   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_5
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#     VIF_Factor            Feature
# 0     6.235435            건물면적(㎡)
# 1     5.067481                  층
# 2   141.259929            KOSPI종가
# 3    35.806708            Fed기준금리
# 4    62.782418  국제유가(Dubai)($/배럴)
# 5    10.404056             부동산거래량
# 6    51.669763          회사채3년(평균)
# 7    40.295413            BOK기준금리
# 8     5.555605               건물연식
# 9    15.733455               환율종가
# 10   82.872632          선행지수순환변동치
# 11    5.377212                EPU
# 12  138.487140        장단기금리spread
# 13   27.873516               금값종가
# 14   21.151663                LTV

# %%
X_scaled.drop('KOSPI종가', axis=1, inplace=True)

# %%
# OLS_6
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.519
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                 3.497e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:02:27   Log-Likelihood:             1.3099e+05
# No. Observations:              453170   AIC:                        -2.619e+05
# Df Residuals:                  453155   BIC:                        -2.618e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.6221      0.005    850.248      0.000       4.611       4.633
# 건물면적(㎡)               2.2011      0.004    585.644      0.000       2.194       2.208
# 층                     0.2743      0.003     84.586      0.000       0.268       0.281
# Fed기준금리              -0.1593      0.003    -51.254      0.000      -0.165      -0.153
# 국제유가(Dubai)($/배럴)     0.1444      0.004     40.156      0.000       0.137       0.151
# 부동산거래량                0.0142      0.002      7.429      0.000       0.010       0.018
# 회사채3년(평균)             0.1328      0.004     36.604      0.000       0.126       0.140
# BOK기준금리              -0.1922      0.004    -49.942      0.000      -0.200      -0.185
# 건물연식                 -0.0044      0.002     -2.534      0.011      -0.008      -0.001
# 환율종가                  0.0351      0.003     12.674      0.000       0.030       0.040
# 선행지수순환변동치             0.1787      0.003     64.088      0.000       0.173       0.184
# EPU                  -0.0181      0.002     -9.555      0.000      -0.022      -0.014
# 장단기금리spread          -0.3209      0.006    -55.755      0.000      -0.332      -0.310
# 금값종가                 -0.0403      0.004     -9.766      0.000      -0.048      -0.032
# LTV                  -0.2739      0.002   -147.031      0.000      -0.278      -0.270
# ==============================================================================
# Omnibus:                    11035.492   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12577.533
# Skew:                           0.350   Prob(JB):                         0.00
# Kurtosis:                       3.419   Cond. No.                         59.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_6
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#     VIF_Factor            Feature
# 0     6.228965            건물면적(㎡)
# 1     5.060867                  층
# 2    35.806157            Fed기준금리
# 3    60.986303  국제유가(Dubai)($/배럴)
# 4     9.690113             부동산거래량
# 5    45.104037          회사채3년(평균)
# 6    37.338149            BOK기준금리
# 7     5.542853               건물연식
# 8    15.464935               환율종가
# 9    41.530862          선행지수순환변동치
# 10    5.373048                EPU
# 11  130.949563        장단기금리spread
# 12   10.157031               금값종가
# 13   20.516881                LTV

# %%
X_scaled.drop('장단기금리spread', axis=1, inplace=True)

# %%
# OLS_7
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                 3.716e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:03:09   Log-Likelihood:             1.2944e+05
# No. Observations:              453170   AIC:                        -2.589e+05
# Df Residuals:                  453156   BIC:                        -2.587e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.5128      0.005    886.998      0.000       4.503       4.523
# 건물면적(㎡)               2.2050      0.004    584.772      0.000       2.198       2.212
# 층                     0.2755      0.003     84.670      0.000       0.269       0.282
# Fed기준금리              -0.1119      0.003    -37.302      0.000      -0.118      -0.106
# 국제유가(Dubai)($/배럴)     0.0940      0.003     26.904      0.000       0.087       0.101
# 부동산거래량               -0.0105      0.002     -5.639      0.000      -0.014      -0.007
# 회사채3년(평균)            -0.0473      0.002    -28.492      0.000      -0.051      -0.044
# BOK기준금리              -0.0968      0.003    -27.987      0.000      -0.104      -0.090
# 건물연식                 -0.0031      0.002     -1.771      0.077      -0.007       0.000
# 환율종가                  0.0354      0.003     12.750      0.000       0.030       0.041
# 선행지수순환변동치             0.0739      0.002     35.759      0.000       0.070       0.078
# EPU                  -0.0284      0.002    -14.973      0.000      -0.032      -0.025
# 금값종가                  0.0386      0.004      9.915      0.000       0.031       0.046
# LTV                  -0.2524      0.002   -138.018      0.000      -0.256      -0.249
# ==============================================================================
# Omnibus:                    11231.156   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12719.504
# Skew:                           0.357   Prob(JB):                         0.00
# Kurtosis:                       3.405   Cond. No.                         48.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_scaled.drop('건물연식', axis=1, inplace=True)

# %%
# OLS_8
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                 4.026e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:03:39   Log-Likelihood:             1.2944e+05
# No. Observations:              453170   AIC:                        -2.589e+05
# Df Residuals:                  453157   BIC:                        -2.587e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 4.5116      0.005    894.543      0.000       4.502       4.521
# 건물면적(㎡)               2.2052      0.004    585.351      0.000       2.198       2.213
# 층                     0.2766      0.003     86.519      0.000       0.270       0.283
# Fed기준금리              -0.1121      0.003    -37.369      0.000      -0.118      -0.106
# 국제유가(Dubai)($/배럴)     0.0940      0.003     26.907      0.000       0.087       0.101
# 부동산거래량               -0.0105      0.002     -5.623      0.000      -0.014      -0.007
# 회사채3년(평균)            -0.0473      0.002    -28.520      0.000      -0.051      -0.044
# BOK기준금리              -0.0967      0.003    -27.963      0.000      -0.103      -0.090
# 환율종가                  0.0353      0.003     12.725      0.000       0.030       0.041
# 선행지수순환변동치             0.0739      0.002     35.797      0.000       0.070       0.078
# EPU                  -0.0283      0.002    -14.940      0.000      -0.032      -0.025
# 금값종가                  0.0385      0.004      9.885      0.000       0.031       0.046
# LTV                  -0.2524      0.002   -138.083      0.000      -0.256      -0.249
# ==============================================================================
# Omnibus:                    11131.609   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12585.911
# Skew:                           0.356   Prob(JB):                         0.00
# Kurtosis:                       3.400   Cond. No.                         47.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_8
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#     VIF_Factor            Feature
# 0     6.215299            건물면적(㎡)
# 1     4.901902                  층
# 2    32.306968            Fed기준금리
# 3    54.119274  국제유가(Dubai)($/배럴)
# 4     8.743632             부동산거래량
# 5     9.998158          회사채3년(평균)
# 6    33.929278            BOK기준금리
# 7    14.297679               환율종가
# 8    17.533827          선행지수순환변동치
# 9     5.240971                EPU
# 10    9.618586               금값종가
# 11   20.300184                LTV

# %%
X_scaled.drop('국제유가(Dubai)($/배럴)', axis=1, inplace=True)

# %%
# OLS_9
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                 4.378e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:04:17   Log-Likelihood:             1.2908e+05
# No. Observations:              453170   AIC:                        -2.581e+05
# Df Residuals:                  453158   BIC:                        -2.580e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.5489      0.005    937.262      0.000       4.539       4.558
# 건물면적(㎡)        2.2065      0.004    585.264      0.000       2.199       2.214
# 층              0.2766      0.003     86.447      0.000       0.270       0.283
# Fed기준금리       -0.0622      0.002    -26.360      0.000      -0.067      -0.058
# 부동산거래량         0.0050      0.002      2.835      0.005       0.002       0.008
# 회사채3년(평균)     -0.0307      0.002    -19.913      0.000      -0.034      -0.028
# BOK기준금리       -0.1014      0.003    -29.341      0.000      -0.108      -0.095
# 환율종가           0.0002      0.002      0.098      0.922      -0.005       0.005
# 선행지수순환변동치      0.0674      0.002     32.843      0.000       0.063       0.071
# EPU           -0.0133      0.002     -7.341      0.000      -0.017      -0.010
# 금값종가           0.0312      0.004      8.020      0.000       0.024       0.039
# LTV           -0.2525      0.002   -138.026      0.000      -0.256      -0.249
# ==============================================================================
# Omnibus:                    11222.152   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12675.125
# Skew:                           0.358   Prob(JB):                         0.00
# Kurtosis:                       3.398   Cond. No.                         43.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_scaled.drop('환율종가', axis=1, inplace=True)

# %%
# OLS_10
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                 4.816e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:04:51   Log-Likelihood:             1.2908e+05
# No. Observations:              453170   AIC:                        -2.581e+05
# Df Residuals:                  453159   BIC:                        -2.580e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.5491      0.004   1121.518      0.000       4.541       4.557
# 건물면적(㎡)        2.2065      0.004    585.315      0.000       2.199       2.214
# 층              0.2766      0.003     86.448      0.000       0.270       0.283
# Fed기준금리       -0.0622      0.002    -26.382      0.000      -0.067      -0.058
# 부동산거래량         0.0050      0.002      2.835      0.005       0.002       0.008
# 회사채3년(평균)     -0.0307      0.002    -19.974      0.000      -0.034      -0.028
# BOK기준금리       -0.1015      0.003    -31.101      0.000      -0.108      -0.095
# 선행지수순환변동치      0.0673      0.002     40.203      0.000       0.064       0.071
# EPU           -0.0133      0.002     -7.432      0.000      -0.017      -0.010
# 금값종가           0.0311      0.004      8.343      0.000       0.024       0.038
# LTV           -0.2525      0.002   -138.048      0.000      -0.256      -0.249
# ==============================================================================
# Omnibus:                    11221.830   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12674.668
# Skew:                           0.358   Prob(JB):                         0.00
# Kurtosis:                       3.398   Cond. No.                         37.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_10
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#    VIF_Factor    Feature
# 0    6.135955    건물면적(㎡)
# 1    4.870157          층
# 2   20.426703    Fed기준금리
# 3    7.033349     부동산거래량
# 4    8.172776  회사채3년(평균)
# 5   31.569621    BOK기준금리
# 6   14.220030  선행지수순환변동치
# 7    3.797961        EPU
# 8    7.543815       금값종가
# 9   18.326758        LTV

# %%
X_scaled.drop('BOK기준금리', axis=1, inplace=True)

# %%
# OLS_11
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                 5.329e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:05:22   Log-Likelihood:             1.2859e+05
# No. Observations:              453170   AIC:                        -2.572e+05
# Df Residuals:                  453160   BIC:                        -2.571e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4594      0.003   1562.822      0.000       4.454       4.465
# 건물면적(㎡)        2.2055      0.004    584.438      0.000       2.198       2.213
# 층              0.2766      0.003     86.364      0.000       0.270       0.283
# Fed기준금리       -0.1050      0.002    -54.854      0.000      -0.109      -0.101
# 부동산거래량         0.0299      0.002     18.959      0.000       0.027       0.033
# 회사채3년(평균)     -0.0222      0.002    -14.689      0.000      -0.025      -0.019
# 선행지수순환변동치      0.0814      0.002     50.469      0.000       0.078       0.085
# EPU            0.0027      0.002      1.577      0.115      -0.001       0.006
# 금값종가           0.1094      0.003     39.850      0.000       0.104       0.115
# LTV           -0.2588      0.002   -142.168      0.000      -0.262      -0.255
# ==============================================================================
# Omnibus:                    11362.701   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12834.087
# Skew:                           0.361   Prob(JB):                         0.00
# Kurtosis:                       3.398   Cond. No.                         25.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_scaled.drop('EPU', axis=1, inplace=True)

# %%
# OLS_12
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                 5.995e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:05:48   Log-Likelihood:             1.2859e+05
# No. Observations:              453170   AIC:                        -2.572e+05
# Df Residuals:                  453161   BIC:                        -2.571e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4611      0.003   1687.419      0.000       4.456       4.466
# 건물면적(㎡)        2.2054      0.004    584.455      0.000       2.198       2.213
# 층              0.2766      0.003     86.373      0.000       0.270       0.283
# Fed기준금리       -0.1051      0.002    -54.903      0.000      -0.109      -0.101
# 부동산거래량         0.0294      0.002     19.014      0.000       0.026       0.032
# 회사채3년(평균)     -0.0229      0.001    -15.703      0.000      -0.026      -0.020
# 선행지수순환변동치      0.0808      0.002     51.614      0.000       0.078       0.084
# 금값종가           0.1092      0.003     39.821      0.000       0.104       0.115
# LTV           -0.2589      0.002   -142.346      0.000      -0.262      -0.255
# ==============================================================================
# Omnibus:                    11356.579   Durbin-Watson:                   1.908
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12826.607
# Skew:                           0.361   Prob(JB):                         0.00
# Kurtosis:                       3.398   Cond. No.                         25.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_12
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#    VIF_Factor    Feature
# 0    5.790442    건물면적(㎡)
# 1    4.755063          층
# 2    3.567679    Fed기준금리
# 3    6.429084     부동산거래량
# 4    7.745816  회사채3년(평균)
# 5   13.031604  선행지수순환변동치
# 6    6.439669       금값종가
# 7    7.340875        LTV

# %%
X_scaled.drop('선행지수순환변동치', axis=1, inplace=True)

# %%
# OLS_13
# 스케일링 후 predict
import statsmodels.api as sm

feature_add = sm.add_constant(X_scaled, has_constant='add')

# sm OLS 적합
model = sm.OLS(y_scaled , feature_add)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               물건금액(만원)   R-squared:                       0.511
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                 6.774e+04
# Date:                Thu, 29 Jun 2023   Prob (F-statistic):               0.00
# Time:                        11:06:36   Log-Likelihood:             1.2726e+05
# No. Observations:              453170   AIC:                        -2.545e+05
# Df Residuals:                  453162   BIC:                        -2.544e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4543      0.003   1682.002      0.000       4.449       4.459
# 건물면적(㎡)        2.2164      0.004    586.610      0.000       2.209       2.224
# 층              0.2801      0.003     87.239      0.000       0.274       0.286
# Fed기준금리       -0.0961      0.002    -50.250      0.000      -0.100      -0.092
# 부동산거래량         0.0331      0.002     21.355      0.000       0.030       0.036
# 회사채3년(평균)      0.0306      0.001     29.777      0.000       0.029       0.033
# 금값종가           0.0954      0.003     34.843      0.000       0.090       0.101
# LTV           -0.2193      0.002   -132.591      0.000      -0.223      -0.216
# ==============================================================================
# Omnibus:                    11347.466   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12746.313
# Skew:                           0.363   Prob(JB):                         0.00
# Kurtosis:                       3.383   Cond. No.                         23.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# VIF_13
vif = feature_engineering_XbyVIF(X_scaled)
print(vif)
# Out:
#    VIF_Factor    Feature
# 0    5.779322    건물면적(㎡)
# 1    4.754412          층
# 2    3.535501    Fed기준금리
# 3    6.417366     부동산거래량
# 4    3.838806  회사채3년(평균)
# 5    6.169922       금값종가
# 6    3.987940        LTV

# %% [markdown]
# ---

# %%
# 교차 검증 수행
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

mlr = LinearRegression()

cross_val_scores = cross_val_score(mlr, X_scaled, y_scaled, scoring='neg_mean_squared_error', cv=5)
cross_val_rmse_scores = np.sqrt(-cross_val_scores)
avg_cross_val_rmse = np.mean(cross_val_rmse_scores)
print('Average Cross-Validated RMSE: {:.3f}'.format(avg_cross_val_rmse))
print(f'교차검증별 MSE : {np.round(-cross_val_scores,4)}')
print(f'교차검증 평균 MSE : {np.round(np.mean(-cross_val_scores),5)}')
# Out:
# Average Cross-Validated RMSE: 0.194
# 교차검증별 MSE : [0.0297 0.0322 0.0347 0.0486 0.0443]
# 교차검증 평균 MSE : 0.03793

# %%
X_scaled.columns
# Out:
# Index(['건물면적(㎡)', '층', 'Fed기준금리', '부동산거래량', '회사채3년(평균)', '금값종가', 'LTV'], dtype='object')

# %%
X_test_scaled.columns
# Out:
# Index(['건물면적(㎡)', '층', 'KOSPI종가', 'Fed기준금리', '국제유가(Dubai)($/배럴)', '부동산거래량',
#        '국고채5년(평균)', '국고채10년(평균)', '회사채3년(평균)', 'CD91물(평균)', 'BOK기준금리', '건물연식',
#        'GDP대비가계부채비율', '환율종가', '선행지수순환변동치', 'EPU', '장단기금리spread', '금값종가',
#        'LTV'],
#       dtype='object')

# %%
X_test_scaled.drop(['장단기금리spread','KOSPI종가', '국제유가(Dubai)($/배럴)','국고채5년(평균)', '국고채10년(평균)',
                     'CD91물(평균)', 'BOK기준금리','환율종가', '선행지수순환변동치','GDP대비가계부채비율', '건물연식', 'EPU'], axis=1, inplace=True)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.model_selection import cross_validate
mlr = LinearRegression()
# 모델을 훈련하고 교차 검증을 수행
cv_results = cross_validate(mlr, X_scaled, y_scaled, cv=5, return_estimator=True)

# 교차 검증 결과에서 각 폴드에서 훈련된 모델을 가져옴
trained_models = cv_results['estimator']
# 각 폴드에서 훈련된 모델을 테스트 데이터에 적용
for model in trained_models:
    y_pred = model.predict(X_test_scaled)
    # 예측 결과를 활용하여 원하는 작업을 수행
    mse = mean_squared_error(y_test_scaled, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test_scaled,y_pred)
    print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
    print('Variance score : {0: .3f}'.format(r2_score(y_test_scaled, y_pred)))
    print('\n')
# Out:
# MSE : 0.046102763311529106, RMSE :  0.215, MAE: 0.215
# Variance score :  0.623
#
#
# MSE : 0.0438491852811287, RMSE :  0.209, MAE: 0.209
# Variance score :  0.642
#
#
# MSE : 0.04584119848217788, RMSE :  0.214, MAE: 0.214
# Variance score :  0.625
#
#
# MSE : 0.04355902869096633, RMSE :  0.209, MAE: 0.209
# Variance score :  0.644
#
#
# MSE : 0.07110826496417655, RMSE :  0.267, MAE: 0.267
# Variance score :  0.419

# %%
from sklearn.model_selection import cross_validate

y_pred = trained_models[3].predict(X_test_scaled)

mse = mean_squared_error(y_test_scaled, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_scaled,y_pred)

print('MSE : {0:}, RMSE : {1: .3f}, MAE:{1: .3f}'.format(mse, rmse, mae))
print('Variance score : {0: .3f}'.format(r2_score(y_test_scaled, y_pred)))
# Out:
# MSE : 0.04355902869096633, RMSE :  0.209, MAE: 0.209
# Variance score :  0.644

# %%
# test 계수 결과 DF 

test_result = pd.DataFrame(data= X_test_scaled.columns)
test_result.columns = ['features']

test_result['coefficient'] = trained_models[3].coef_

test_result.sort_values('coefficient', ascending=False)
# Out:
#     features  coefficient
# 0    건물면적(㎡)     2.154958
# 1          층     0.256609
# 5       금값종가     0.023337
# 3     부동산거래량     0.011306
# 4  회사채3년(평균)    -0.009783
# 2    Fed기준금리    -0.115769
# 6        LTV    -0.314571

# %% [markdown]
# ---

# %% [markdown]
# # 잔차항 검정
# 1. 정규성
# 2. 등분산성
# 3. 독립성

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats

import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # windows
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac
matplotlib.rcParams['font.size'] = 15  # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용시 마이너스 꺠지지않게 해줌

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import math

x = X_scaled_5
y = y_scaled

# 모델 적합
model = sm.OLS(y, x)  # 종속 변수 y와 독립 변수 X를 지정하여 모델 생성
result = model.fit()  # 모델 적합

# 잔차 추출
residuals = result.resid

# 잔차 분석
# 잔차의 정규성 확인: 잔차의 분포를 정규분포와 비교하여 정규성 검정을 수행합니다.
sm.qqplot(residuals, line='s')  # Q-Q plot을 그려서 정규성 확인
plt.xlabel('이론적인 분위수')
plt.ylabel('잔차')
plt.title('잔차의 Q-Q 플롯')
plt.show()

# 잔차의 등분산성 확인: 잔차와 예측값 사이의 관계를 살펴서 등분산성을 확인합니다.
plt.scatter(result.fittedvalues, residuals)
plt.xlabel('예측값')
plt.ylabel('잔차')
plt.title('예측값과 잔차의 산점도')
plt.axhline(y=0, color='red', linestyle='--')  # 잔차가 0인 기준선 추가
plt.show()

# 잔차의 독립성 확인: 잔차와 독립 변수 간의 관계를 살펴서 독립성을 확인합니다.
num_cols = len(x.columns)
num_rows = math.ceil(num_cols / 3)  # 3개의 열로 나누어 출력하고자 한다면
fig, axes = plt.subplots(num_rows, 3, figsize=(15, num_rows*5))
for i in range(num_cols):
    row = i // 3
    col = i % 3
    ax = axes[row, col]
    ax.scatter(x.iloc[:, i], residuals)
    ax.set_xlabel('독립 변수')
    ax.set_ylabel('잔차')
    ax.set_title(f'{x.columns[i]}과 잔차의 산점도')
    ax.axhline(y=0, color='red', linestyle='--')  # 잔차가 0인 기준선 추가

plt.tight_layout()  # 그래프 간격 조정
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 5
#       2 import matplotlib.pyplot as plt
#       3 import math
# ----> 5 x = X_scaled_5
#       6 y = y_scaled
#       8 # 모델 적합
#
# NameError: name 'X_scaled_5' is not defined
