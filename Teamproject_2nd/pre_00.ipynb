# %%
import pandas as pd

# %%
df0 = pd.read_excel('./dataset_final/삭제전DF.xlsx', index_col=0)
df1 = pd.read_excel('./dataset_final/비재무_최종_df.xlsx', index_col=0)

# %%
print(df0.shape)
df1.shape
# Out:
# (17487, 70)
# (17487, 17)

# %%
df0.columns
# Out:
# Index(['회사명', '시장종류', '거래소코드', '회계연도', '상장일', 'label', '평균근속연수', '설립일',
#        '주거래은행', 'R&D 비용', '업력', '임원진 주식 보유', '최대주주변경 횟수', '감사법인 변경 횟수',
#        '수출기업여부', '직원수 증감', '기간제비율', '통계청 한국표준산업분류 10차(중분류)', '표준편차',
#        '산업위험(경기민감도에 따른)', '연도', '시총기준산업위험', '회계년도', '[제조]유동비율(IFRS연결)',
#        '[제조]당좌비율(IFRS연결)', '[제조]유동부채비율(IFRS연결)', '[제조]비유동비율(IFRS연결)',
#        '[제조]순운전자본비율(IFRS연결)', '[제조]부채비율(IFRS연결)', '[제조]차입금의존도(IFRS연결)',
#        '[제조]비유동장기적합률(IFRS연결)', '[제조]자기자본순이익률(IFRS연결)', '[제조]총자본순이익률(IFRS연결)',
#        '[제조]자기자본정상영업이익률(IFRS연결)', '[제조]총자본정상영업이익률(IFRS연결)',
#        '[제조]경영자본순이익률(IFRS연결)', '[제조]매출액순이익률(IFRS연결)',
#        '[제조]이자보상배율(이자비용)(IFRS연결)', '[제조]금융비용부담률(IFRS연결)',
#        '[제조]매출액정상영업이익률(IFRS연결)', '[제조]당좌자산회전률(IFRS연결)', '[제조]재고자산회전률(IFRS연결)',
#        '[제조]자기자본회전률(IFRS연결)', '[제조]경영자본회전률(IFRS연결)', '[제조]매출채권회전률(IFRS연결)',
#        '[제조]매입채무회전률(IFRS연결)', '[제조]유형자산회전율(IFRS연결)', '[제조]매출액증가율(IFRS연결)',
# ...

# %%
df1.columns
# Out:
# Index(['회사명', '시장종류', '거래소코드', '회계연도', '주거래은행', '평균근속연수', 'R&D비용', '업력',
#        '대주주 보유 주식 비율', '최대주주변경 횟수', '감사법인 변경 횟수', '직원수 증감', '수출기업여부', '기간제비율',
#        '통계청 한국표준산업분류 10차(중분류)', '산업위험(경기민감도에 따른)', 'Target'],
#       dtype='object')

# %%
df0.iloc[:,23: ]
# Out:
#        [제조]유동비율(IFRS연결)  [제조]당좌비율(IFRS연결)  [제조]유동부채비율(IFRS연결)  \
# 0                200.97            165.03               42.33
# 1                693.49            649.98               21.50
# 2                694.71            610.74               11.23
# 3                324.58            268.23               17.79
# 4                296.85            235.21               18.91
# ...                 ...               ...                 ...
# 17482            329.17            290.09                5.40
# 17483            485.39            422.76                6.05
# 17484           1108.08           1013.02                3.14
# 17485            913.64            818.58                3.68
# 17486            185.24            115.48                5.84
#
#        [제조]비유동비율(IFRS연결)  [제조]순운전자본비율(IFRS연결)  [제조]부채비율(IFRS연결)  \
# 0                  66.34                28.23             51.41
# 1                  31.65                70.60             80.77
# ...

# %%
main_df = pd.concat([df1.iloc[:, :], df0.iloc[:,23: ]], axis=1)
main_df.drop('시장종류', axis=1, inplace=True)

# %%
main_df
# Out:
#             회사명  거래소코드     회계연도    주거래은행  평균근속연수  R&D비용  업력  대주주 보유 주식 비율  \
# 0      (주)CMG제약  58820  2011/12  KEB하나은행    3.10   3.32  10        2.3100
# 1      (주)CMG제약  58820  2012/12  KEB하나은행    2.90   2.58  11       30.2900
# 2      (주)CMG제약  58820  2013/12  KEB하나은행    3.94  25.21  12       26.8000
# 3      (주)CMG제약  58820  2014/12  KEB하나은행    2.69  18.64  13       26.8000
# 4      (주)CMG제약  58820  2015/12  KEB하나은행    3.31  22.22  14       26.2900
# ...         ...    ...      ...      ...     ...    ...  ..           ...
# 17482   흥구석유(주)  24060  2018/12  DGB대구은행     NaN   0.00  24        9.3625
# 17483   흥구석유(주)  24060  2019/12  DGB대구은행     NaN   0.00  25        8.8900
# 17484   흥구석유(주)  24060  2020/12  DGB대구은행     NaN   0.00  26        8.5575
# 17485   흥구석유(주)  24060  2021/12  DGB대구은행     NaN   0.00  27        8.5575
# 17486   흥구석유(주)  24060  2022/12  DGB대구은행     NaN   0.00  28        8.5575
#
#        최대주주변경 횟수  감사법인 변경 횟수  ...  PPI(2015기준)  실질GDP성장률(%)     외화포지션  \
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17487 entries, 0 to 17486
# Data columns (total 63 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   회사명                           17487 non-null  object
#  1   거래소코드                         17487 non-null  int64
#  2   회계연도                          17487 non-null  object
#  3   주거래은행                         17474 non-null  object
#  4   평균근속연수                        11082 non-null  float64
#  5   R&D비용                         15711 non-null  float64
#  6   업력                            17487 non-null  int64
#  7   대주주 보유 주식 비율                  14729 non-null  float64
#  8   최대주주변경 횟수                     17487 non-null  int64
#  9   감사법인 변경 횟수                    17487 non-null  int64
#  10  직원수 증감                        13724 non-null  float64
#  11  수출기업여부                        17487 non-null  int64
# ...

# %%
main_df.columns = ['회사명', '거래소코드', '회계년도', '주거래은행', '평균근속연수(년)','R&D집중도(%)',
       '업력(년)', '최대주주특수관계인_지분율(%)', '최대주주변경횟수(회)', '감사법인변경횟수(회)', '직원수증감율(%)','수출기업여부(dummy)',
       '기간제비율(%)', '표준산업분류_중분류', '산업위험_경기민감도', 'Target',
       '유동비율(%)', '당좌비율(%)', '유동부채비율(%)',
       '비유동비율(%)', '순운전자본비율(%)', '부채비율(%)',
       '차입금의존도(%)', '비유동장기적합률(%)', '자기자본순이익률(%)',
       '총자본순이익률(%)', '자기자본정상영업이익률(%)',
       '총자본정상영업이익률(%)', '경영자본순이익률(%)', '매출액순이익률(%)',
       '이자보상배율(이자비용)(배)', '금융비용부담률(%)',
       '매출액정상영업이익률(%)', '당좌자산회전률(배)', '재고자산회전률(배)',
       '자기자본회전률(배)', '경영자본회전률(배)', '매출채권회전률(배)',
       '매입채무회전률(배)', '유형자산회전율(배)', '매출액증가율(%)',
       '순이익증가율(%)', '정상영업이익증가율(%)', '유동자산증가율(%)',
       '평균총자산(천원)', '매출액(수익)(천원)', '청산가치율(삭제)','이익잉여금비율(%)', '총자산회전율(%->배)',
       '총자산_증가율(배->%)', 'CASH FLOW 대 부채비율(%)', '총자본투자효율(%)',
       'spread(%)', 'PPI(2015기준)', '실질GDP성장률(%)', '외화포지션(배->%)', 'K2_score',
       'K2_부실판단', 'EV/EBITDA(배)', '52주베타(배)', 'PER', 'PBR', 'PCR']

# %%
main_df['회계년도'] =pd.to_datetime(main_df['회계년도']).dt.year

# %%
main_df.drop('청산가치율(삭제)', axis = 1, inplace=True)

# %%
main_df.to_excel('./main_df.xlsx')

# %% [markdown]
# ---

# %%
df_main = pd.concat([df1.iloc[:, 0:14], df0.iloc[:,23: ]], axis=1)

# %%
main_df = pd.concat([df_main, df0[['label']]], axis=1)

# %%
main_df = main_df.loc[~((main_df['label']=='삭제')|(main_df['label']=='삭제 '))]

# %%
main_df['label'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11248 entries, 0 to 17486
# Data columns (total 62 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   회사명                           11248 non-null  object
#  1   시장종류                          11248 non-null  object
#  2   거래소코드                         11248 non-null  int64
#  3   회계연도                          11248 non-null  object
#  4   주거래은행                         11243 non-null  object
#  5   R&D비용                         11141 non-null  float64
#  6   업력                            11248 non-null  int64
#  7   대주주 보유 주식 비율                  11219 non-null  float64
#  8   최대주주변경 횟수                     11248 non-null  int64
#  9   감사법인 변경 횟수                    11248 non-null  int64
#  10  직원수 증감                        11105 non-null  float64
#  11  기간제비율                         11168 non-null  float64
# ...

# %%
main_df['연도'] = pd.to_datetime(main_df['회계연도']).dt.year

# %%
main_df[main_df['연도']> 2017]
# Out:
# 0    5300
# 1     500
# Name: label, dtype: int64
